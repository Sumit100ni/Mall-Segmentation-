# %% [markdown]
# # Context
# This data set is created only for the learning purpose of the customer segmentation concepts , also known as market basket analysis . I will demonstrate this by using unsupervised ML technique (KMeans Clustering Algorithm) in the simplest form.
#
# # Content
# You are owing a supermarket mall and through membership cards , you have some basic data about your customers like Customer ID, age, gender, annual income and spending score.
# Spending Score is something you assign to the customer based on your defined parameters like customer behavior and purchasing data.
#
# # Problem Statement
# You own the mall and want to understand the customers like who can be easily converge [Target Customers] so that the sense can be given to marketing team and plan the strategy accordingly.

# %% [markdown]
# # Name:-Darpan Relan
#
# # Project Name:-Customer Segmentation
#
# # Institute Name:-Board Infinity
#
# # Submitted To:-Mr. Shrikant

# %% [markdown]
# ## Importing Libraries & Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## IMPORTING data

# %%
data=pd.read_csv('Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.shape
# Out:
# (200, 5)

# %% [markdown]
# ## finding null values

# %%
data.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ## data visualization

# %%
plt.style.use('fivethirtyeight')

# %%
plt.figure(1,figsize=(20,10))
n=0
for x in ['Age','Annual Income (k$)','Spending Score (1-100)']:
    n+=1
    plt.subplot(1,3,n)
    plt.subplots_adjust(hspace=0.5,wspace=0.5)
    sns.distplot(data[x],bins=5)
    plt.title('distance plot of {}'.format(x))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(1,figsize=(15,5))
sns.countplot(y='Gender',data=data)
plt.xlabel('Count Of Male & Female')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## plotting the relation between age, annual income and spending score

# %%
plt.figure(1,figsize=(15,10))
n=0
for x in ['Age' , 'Annual Income (k$)' , 'Spending Score (1-100)']:
    for y in ['Age' , 'Annual Income (k$)' , 'Spending Score (1-100)']:
        n+=1
        plt.subplot(3,3,n)
        plt.subplots_adjust(hspace=0.5,wspace=0.5)
        sns.regplot(x=x,y=y,data=data,color='g')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.figure(1,figsize=(15,5))
for gender in ['Male','Female']:
    plt.scatter(x='Age',y='Annual Income (k$)',data=data[data['Gender']==gender],s=200,alpha=0.5,label=gender)
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.title('Age vs Annual Income(k$) w.r.t Gender')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(1 , figsize = (15 , 6))
for gender in ['Male' , 'Female']:
    plt.scatter(x = 'Annual Income (k$)',y = 'Spending Score (1-100)',data = data[data['Gender'] == gender] ,s = 200 , alpha = 0.5 , label = gender)
plt.xlabel('Annual Income (k$)'), plt.ylabel('Spending Score (1-100)') 
plt.title('Annual Income vs Spending Score w.r.t Gender')
plt.legend()
plt.show()

# %% [markdown]
# ## as we see the pattern in it so clustering would be better annual income and spending score

# %%
plt.figure(1,figsize=(15,5))
n=0
for cols in ['Age' , 'Annual Income (k$)' , 'Spending Score (1-100)']:
    n+=1
    plt.subplot(1,3,n)
    plt.subplots_adjust(hspace=0.5,wspace=0.5)
    sns.swarmplot(x=cols,y='Gender',data=data)
    sns.violinplot(x=cols,y='Gender',data=data)
    plt.ylabel('Gender')
    plt.title('Boxplots & Swarmplots')
plt.show()

# %% [markdown]
# ## clustering using k means

# %% [markdown]
# ## now finding the best n clusters using elbow method

# %%
from sklearn.cluster import KMeans 
from sklearn import metrics 
from scipy.spatial.distance import cdist

# %%
x1 = data[['Age' , 'Spending Score (1-100)','Annual Income (k$)']].iloc[: , :].values
x1
# Out:
# array([[ 19,  39,  15],
#        [ 21,  81,  15],
#        [ 20,   6,  16],
#        [ 23,  77,  16],
#        [ 31,  40,  17],
#        [ 22,  76,  17],
#        [ 35,   6,  18],
#        [ 23,  94,  18],
#        [ 64,   3,  19],
#        [ 30,  72,  19],
#        [ 67,  14,  19],
#        [ 35,  99,  19],
#        [ 58,  15,  20],
#        [ 24,  77,  20],
#        [ 37,  13,  20],
#        [ 22,  79,  20],
#        [ 35,  35,  21],
#        [ 20,  66,  21],
#        [ 52,  29,  23],
#        [ 35,  98,  23],
#        [ 35,  35,  24],
#        [ 25,  73,  24],
#        [ 46,   5,  25],
#        [ 31,  73,  25],
#        [ 54,  14,  28],
#        [ 29,  82,  28],
#        [ 45,  32,  28],
#        [ 35,  61,  28],
#        [ 40,  31,  29],
#        [ 23,  87,  29],
#        [ 60,   4,  30],
#        [ 21,  73,  30],
#        [ 53,   4,  33],
#        [ 18,  92,  33],
#        [ 49,  14,  33],
#        [ 21,  81,  33],
#        [ 42,  17,  34],
#        [ 30,  73,  34],
#        [ 36,  26,  37],
#        [ 20,  75,  37],
#        [ 65,  35,  38],
#        [ 24,  92,  38],
#        [ 48,  36,  39],
#        [ 31,  61,  39],
#        [ 49,  28,  39],
#        [ 24,  65,  39],
#        [ 50,  55,  40],
#        [ 27,  47,  40],
#        [ 29,  42,  40],
#        [ 31,  42,  40],
#        [ 49,  52,  42],
#        [ 33,  60,  42],
#        [ 31,  54,  43],
#        [ 59,  60,  43],
#        [ 50,  45,  43],
#        [ 47,  41,  43],
#        [ 51,  50,  44],
#        [ 69,  46,  44],
#        [ 27,  51,  46],
#        [ 53,  46,  46],
#        [ 70,  56,  46],
#        [ 19,  55,  46],
#        [ 67,  52,  47],
#        [ 54,  59,  47],
#        [ 63,  51,  48],
#        [ 18,  59,  48],
#        [ 43,  50,  48],
#        [ 68,  48,  48],
#        [ 19,  59,  48],
#        [ 32,  47,  48],
#        [ 70,  55,  49],
#        [ 47,  42,  49],
#        [ 60,  49,  50],
#        [ 60,  56,  50],
#        [ 59,  47,  54],
#        [ 26,  54,  54],
#        [ 45,  53,  54],
#        [ 40,  48,  54],
#        [ 23,  52,  54],
#        [ 49,  42,  54],
#        [ 57,  51,  54],
#        [ 38,  55,  54],
#        [ 67,  41,  54],
#        [ 46,  44,  54],
#        [ 21,  57,  54],
#        [ 48,  46,  54],
#        [ 55,  58,  57],
#        [ 22,  55,  57],
#        [ 34,  60,  58],
#        [ 50,  46,  58],
#        [ 68,  55,  59],
#        [ 18,  41,  59],
#        [ 48,  49,  60],
#        [ 40,  40,  60],
#        [ 32,  42,  60],
#        [ 24,  52,  60],
#        [ 47,  47,  60],
#        [ 27,  50,  60],
#        [ 48,  42,  61],
#        [ 20,  49,  61],
#        [ 23,  41,  62],
#        [ 49,  48,  62],
#        [ 67,  59,  62],
#        [ 26,  55,  62],
#        [ 49,  56,  62],
#        [ 21,  42,  62],
#        [ 66,  50,  63],
#        [ 54,  46,  63],
#        [ 68,  43,  63],
#        [ 66,  48,  63],
#        [ 65,  52,  63],
#        [ 19,  54,  63],
#        [ 38,  42,  64],
#        [ 19,  46,  64],
#        [ 18,  48,  65],
#        [ 19,  50,  65],
#        [ 63,  43,  65],
#        [ 49,  59,  65],
#        [ 51,  43,  67],
#        [ 50,  57,  67],
#        [ 27,  56,  67],
#        [ 38,  40,  67],
#        [ 40,  58,  69],
#        [ 39,  91,  69],
#        [ 23,  29,  70],
#        [ 31,  77,  70],
#        [ 43,  35,  71],
#        [ 40,  95,  71],
#        [ 59,  11,  71],
#        [ 38,  75,  71],
#        [ 47,   9,  71],
#        [ 39,  75,  71],
#        [ 25,  34,  72],
#        [ 31,  71,  72],
#        [ 20,   5,  73],
#        [ 29,  88,  73],
#        [ 44,   7,  73],
#        [ 32,  73,  73],
#        [ 19,  10,  74],
#        [ 35,  72,  74],
#        [ 57,   5,  75],
#        [ 32,  93,  75],
#        [ 28,  40,  76],
#        [ 32,  87,  76],
#        [ 25,  12,  77],
#        [ 28,  97,  77],
#        [ 48,  36,  77],
#        [ 32,  74,  77],
#        [ 34,  22,  78],
#        [ 34,  90,  78],
#        [ 43,  17,  78],
#        [ 39,  88,  78],
#        [ 44,  20,  78],
#        [ 38,  76,  78],
#        [ 47,  16,  78],
#        [ 27,  89,  78],
#        [ 37,   1,  78],
#        [ 30,  78,  78],
#        [ 34,   1,  78],
#        [ 30,  73,  78],
#        [ 56,  35,  79],
#        [ 29,  83,  79],
#        [ 19,   5,  81],
#        [ 31,  93,  81],
#        [ 50,  26,  85],
#        [ 36,  75,  85],
#        [ 42,  20,  86],
#        [ 33,  95,  86],
#        [ 36,  27,  87],
#        [ 32,  63,  87],
#        [ 40,  13,  87],
#        [ 28,  75,  87],
#        [ 36,  10,  87],
#        [ 36,  92,  87],
#        [ 52,  13,  88],
#        [ 30,  86,  88],
#        [ 58,  15,  88],
#        [ 27,  69,  88],
#        [ 59,  14,  93],
#        [ 35,  90,  93],
#        [ 37,  32,  97],
#        [ 32,  86,  97],
#        [ 46,  15,  98],
#        [ 29,  88,  98],
#        [ 41,  39,  99],
#        [ 30,  97,  99],
#        [ 54,  24, 101],
#        [ 28,  68, 101],
#        [ 41,  17, 103],
#        [ 36,  85, 103],
#        [ 34,  23, 103],
#        [ 32,  69, 103],
#        [ 33,   8, 113],
#        [ 38,  91, 113],
#        [ 47,  16, 120],
#        [ 35,  79, 120],
#        [ 45,  28, 126],
#        [ 32,  74, 126],
#        [ 32,  18, 137],
#        [ 30,  83, 137]], dtype=int64)

# %%
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,11) 
  
for k in K: 
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=k).fit(x1) 
    kmeanModel.fit(x1)     
      
    distortions.append(sum(np.min(cdist(x1, kmeanModel.cluster_centers_, 
                      'euclidean'),axis=1)) / x1.shape[0]) 
    inertias.append(kmeanModel.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(x1, kmeanModel.cluster_centers_, 
                 'euclidean'),axis=1)) / x1.shape[0] 
    mapping2[k] = kmeanModel.inertia_ 
    
mapping2
# Out:
# {1: 308812.78,
#  2: 212840.16982097187,
#  3: 143342.751571706,
#  4: 104366.15145556198,
#  5: 75350.77917248775,
#  6: 58302.40630860368,
#  7: 51082.54296792137,
#  8: 44307.873416704446,
#  9: 40608.14164169164,
#  10: 37071.80528559619}

# %%
for key,val in mapping1.items(): 
    print(str(key)+' : '+str(val))
# Out:
# 1 : 35.5832677310801
# 2 : 30.11722673262042
# 3 : 24.013910603806483
# 4 : 20.468250917276343
# 5 : 17.764541099376498
# 6 : 15.432713147141996
# 7 : 14.568820226332402
# 8 : 13.848747314242809
# 9 : 13.251548920835067
# 10 : 12.50913436068862

# %%
plt.plot(K, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()

# %% [markdown]
# ## by seeing distortion we got that 5 is the best value for k means ckluster

# %% [markdown]
# ## 1.Segmentation using Age and Spending Score

# %%
x1 = data[['Age' , 'Spending Score (1-100)']].iloc[: , :].values
inertia = []
for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 5 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(x1)
    inertia.append(algorithm.inertia_)

inertia
# Out:
# [171535.5,
#  75949.15601023017,
#  45840.67661610867,
#  28165.58356662934,
#  23839.262483341663,
#  19693.224937088657,
#  15514.19313435103,
#  13054.172145982673,
#  11520.34610781251,
#  10168.277083982011]

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5,c='g')
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
algorithm = (KMeans(n_clusters = 5,init='k-means++', n_init = 5 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
algorithm.fit(x1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

print(centroids1)
pd.DataFrame(labels1)
# Out:
# [[28.08695652 48.84782609]
#  [30.         82.06896552]
#  [50.46666667 16.1       ]
#  [55.70833333 48.22916667]
#  [30.55555556 13.05555556]]
#      0
# 0    0
# 1    1
# 2    4
# 3    1
# 4    0
# ..  ..
# 195  1
# 196  2
# 197  1
# 198  4
# 199  1
#
# [200 rows x 1 columns]

# %%
h = 0.02
x_min, x_max = x1[:, 0].min() - 1, x1[:, 0].max() + 1
y_min, y_max = x1[:, 1].min() - 1, x1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])
Z
# Out:
# array([4, 4, 4, ..., 1, 1, 1])

# %%
plt.figure(1 , figsize = (15 , 7) )
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z , interpolation='nearest', 
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap = plt.cm.Pastel2, aspect = 'auto', origin='lower')

# %%
plt.figure(1 , figsize = (15 , 7) )
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z , interpolation='nearest', 
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap = plt.cm.Pastel2, aspect = 'auto', origin='lower')

plt.scatter( x = 'Age' ,y = 'Spending Score (1-100)' , data = data , c = labels1 , 
            s = 200 )
plt.scatter(x = centroids1[: , 0] , y =  centroids1[: , 1] , s = 300 , c = 'red' , alpha = 0.5)
plt.ylabel('Spending Score (1-100)') , plt.xlabel('Age')
plt.show()

# %%
'''Annual Income and spending Score'''
X2 = data[['Annual Income (k$)' , 'Spending Score (1-100)']].iloc[: , :].values
inertia = []
for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(X2)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
algorithm = (KMeans(n_clusters = 5 ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
algorithm.fit(X2)
labels2 = algorithm.labels_
centroids2 = algorithm.cluster_centers_

# %%
h = 0.02
x_min, x_max = X2[:, 0].min() - 1, X2[:, 0].max() + 1
y_min, y_max = X2[:, 1].min() - 1, X2[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z2 = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# %% [markdown]
# ## K Means Clustering Classification

# %%
plt.figure(1 , figsize = (15 , 7) )
plt.clf()
Z2 = Z2.reshape(xx.shape)
plt.imshow(Z2 , interpolation='nearest', 
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap = plt.cm.Pastel2, aspect = 'auto', origin='lower')

plt.scatter( x = 'Annual Income (k$)' ,y = 'Spending Score (1-100)' , data = data , c = labels2 , 
            s = 200 )
plt.scatter(x = centroids2[: , 0] , y =  centroids2[: , 1] , s = 300 , c = 'red' , alpha = 0.5)
plt.ylabel('Spending Score (1-100)') , plt.xlabel('Annual Income (k$)')
plt.show()

# %%
X3 = data[['Age' , 'Annual Income (k$)' ,'Spending Score (1-100)']].iloc[: , :].values
inertia = []
for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(X3)
    inertia.append(algorithm.inertia_)





plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()





algorithm = (KMeans(n_clusters = 5 ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
algorithm.fit(X3)
labels3 = algorithm.labels_
centroids3 = algorithm.cluster_centers_

# %%
pd.DataFrame(labels3)
# Out:
#      0
# 0    0
# 1    4
# 2    0
# 3    4
# 4    0
# ..  ..
# 195  2
# 196  1
# 197  2
# 198  1
# 199  2
#
# [200 rows x 1 columns]

# %%
centroids3
# Out:
# array([[45.2173913 , 26.30434783, 20.91304348],
#        [40.66666667, 87.75      , 17.58333333],
#        [32.69230769, 86.53846154, 82.12820513],
#        [43.08860759, 55.29113924, 49.56962025],
#        [25.52173913, 26.30434783, 78.56521739]])

# %%
data['Strategy Predictor']=labels3
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Strategy Predictor
# 0                     0
# 1                     4
# 2                     0
# 3                     4
# 4                     0
# ..                  ...
# 195                   2
# 196                   1
# 197                   2
# 198                   1
# 199                   2
#
# [200 rows x 6 columns]

# %%
df['Strategy Predictor'].replace([0],['Age is around 45, salary is around 26, spending score is also less'],inplace=True)
df['Strategy Predictor'].replace([1],['Age is around 40, salary is around 88, spending score is less while salary is high'],inplace=True)
df['Strategy Predictor'].replace([2],['Age is around 32, salary is around 86, spending score is high'],inplace=True)
df['Strategy Predictor'].replace([3],['Age is around 43, salary is around 55, spending score is medium'],inplace=True)
df['Strategy Predictor'].replace([4],['Age is around 25, salary is around 26, spending score is too high but salary is low'],inplace=True)
df
# Out:
#      Unnamed: 0  CustomerID  Gender  Age  Annual Income (k$)  \
# 0             0           1    Male   19                  15
# 1             1           2    Male   21                  15
# 2             2           3  Female   20                  16
# 3             3           4  Female   23                  16
# 4             4           5  Female   31                  17
# ..          ...         ...     ...  ...                 ...
# 195         195         196  Female   35                 120
# 196         196         197  Female   45                 126
# 197         197         198    Male   32                 126
# 198         198         199    Male   32                 137
# 199         199         200    Male   30                 137
#
#      Spending Score (1-100)                                 Strategy Predictor
# 0                        39  Age is around 45, salary is around 26, spendin...
# 1                        81  Age is around 25, salary is around 26, spendin...
# 2                         6  Age is around 45, salary is around 26, spendin...
# 3                        77  Age is around 25, salary is around 26, spendin...
# 4                        40  Age is around 45, salary is around 26, spendin...
# ..                      ...                                                ...
# 195                      79  Age is around 32, salary is around 86, spendin...
# 196                      28  Age is around 40, salary is around 88, spendin...
# 197                      74  Age is around 32, salary is around 86, spendin...
# 198                      18  Age is around 40, salary is around 88, spendin...
# 199                      83  Age is around 32, salary is around 86, spendin...
#
# [200 rows x 7 columns]

# %%
data.to_csv('Strategy decider')
df=pd.read_csv('Strategy decider')
df
# Out:
#      Unnamed: 0  CustomerID  Gender  Age  Annual Income (k$)  \
# 0             0           1    Male   19                  15
# 1             1           2    Male   21                  15
# 2             2           3  Female   20                  16
# 3             3           4  Female   23                  16
# 4             4           5  Female   31                  17
# ..          ...         ...     ...  ...                 ...
# 195         195         196  Female   35                 120
# 196         196         197  Female   45                 126
# 197         197         198    Male   32                 126
# 198         198         199    Male   32                 137
# 199         199         200    Male   30                 137
#
#      Spending Score (1-100)  Strategy Predictor
# 0                        39                   0
# 1                        81                   4
# 2                         6                   0
# 3                        77                   4
# 4                        40                   0
# ..                      ...                 ...
# 195                      79                   2
# 196                      28                   1
# 197                      74                   2
# 198                      18                   1
# 199                      83                   2
#
# [200 rows x 7 columns]

# %%
df.to_csv('final strategy.csv')

# %%
import pickle

# %%
pickle.dump(algorithm,open('model.pkl','wb'))

# %%
model=pickle.load(open('model.pkl','rb'))
model.predict([[20,3,7]])
# Out:
# array([0])

# %%
from flask import Flask,request,jsonify,render_template
app=Flask(__name__)
model=pickle.load(open('model.pkl','rb'))
debug=True
@app.route('/')
def home():
    #return render_template('index')
    return render_template('index.html')
#@app.route('/predict',methods=['POST','GET'])
@app.route('/predict',methods=['POST'])
def predict():
    #print(request.form)
    int_features=[int(x) for x in request.form.values()]
    final_features=[np.array(int_features)]
    prediction=model.predict(final_features)
    
    output=prediction[0]
    
    #return render_template('index',prediction_text='Marketimg Team Needs To contact this person by this strategy {}'.format(output))
    return render_template('index.html',prediction_text='Marketimg Team Needs To contact this person by this strategy {}'.format(output))

if __name__=='__main__':
    app.run()
    
exit
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
